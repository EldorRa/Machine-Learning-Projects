# %% [markdown]
# In this project for analsying the reviews used VADER model
#
# Because of dataset is large, this code written in Kaggle notebook
#
# Dataset:https://www.kaggle.com/datasets/snap/amazon-fine-food-reviews

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

# %%
df = pd.read_csv("/kaggle/input/amazon-fine-food-reviews/Reviews.csv")

# %%
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
#Dataset is big because of this I try to use only 500 rows data
print("Shape of Dataset: ",df.shape)
df_train = df.head(500)
print("Shape df_train: ",df_train.shape)
# Out:
# Shape of Dataset:  (568454, 10)
# Shape df_train:  (500, 10)

# %%
df_train.Score.value_counts()
# Out:
# Score
# 5    339
# 4     70
# 3     37
# 1     36
# 2     18
# Name: count, dtype: int64

# %%
#Now lets visualize the value counts of Score column
ax = df.Score.value_counts().sort_index().plot(kind='bar',
          title='Count of Reviews by Stars',
          figsize=(10, 5))
ax.set_xlabel('Review Stars')
plt.show()

# %%
#Before using nltk, i want to use one example from review and show how the nltk works
review_example = df_train.Text[100]
review_example
# Out:
# 'The mouth says, "How do I love thee, let me count the ways..."<br />If you like apple products a must have item.  The only draw back, shipping cost.  These are very heavy.'

# %%
#Basically nlkt tokenizer splits all words as one
token = nltk.word_tokenize(review_example)
token
# Out:
# ['The',
#  'mouth',
#  'says',
#  ',',
#  '``',
#  'How',
#  'do',
#  'I',
#  'love',
#  'thee',
#  ',',
#  'let',
#  'me',
#  'count',
#  'the',
#  'ways',
#  '...',
#  "''",
#  '<',
#  'br',
#  '/',
#  '>',
#  'If',
#  'you',
#  'like',
#  'apple',
#  'products',
#  'a',
#  'must',
#  'have',
#  'item',
#  '.',
#  'The',
#  'only',
#  'draw',
#  'back',
#  ',',
#  'shipping',
#  'cost',
#  '.',
#  'These',
#  'are',
#  'very',
#  'heavy',
#  '.']

# %%
tagged = nltk.pos_tag(token)
tagged
# Out:
# [('The', 'DT'),
#  ('mouth', 'NN'),
#  ('says', 'VBZ'),
#  (',', ','),
#  ('``', '``'),
#  ('How', 'WRB'),
#  ('do', 'VB'),
#  ('I', 'PRP'),
#  ('love', 'VB'),
#  ('thee', 'NN'),
#  (',', ','),
#  ('let', 'VB'),
#  ('me', 'PRP'),
#  ('count', 'VB'),
#  ('the', 'DT'),
#  ('ways', 'NNS'),
#  ('...', ':'),
#  ("''", "''"),
#  ('<', 'VBZ'),
#  ('br', 'NN'),
#  ('/', 'NNP'),
#  ('>', 'NNP'),
#  ('If', 'IN'),
#  ('you', 'PRP'),
#  ('like', 'VBP'),
#  ('apple', 'NN'),
#  ('products', 'NNS'),
#  ('a', 'DT'),
#  ('must', 'MD'),
#  ('have', 'VB'),
#  ('item', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('only', 'JJ'),
#  ('draw', 'NN'),
#  ('back', 'RB'),
#  (',', ','),
#  ('shipping', 'VBG'),
#  ('cost', 'NN'),
#  ('.', '.'),
#  ('These', 'DT'),
#  ('are', 'VBP'),
#  ('very', 'RB'),
#  ('heavy', 'JJ'),
#  ('.', '.')]

# %%
ent = nltk.chunk.ne_chunk(tagged)
ent.pprint()
# Out:
# (S
#   The/DT
#   mouth/NN
#   says/VBZ
#   ,/,
#   ``/``
#   How/WRB
#   do/VB
#   I/PRP
#   love/VB
#   thee/NN
#   ,/,
#   let/VB
#   me/PRP
#   count/VB
#   the/DT
#   ways/NNS
#   .../:
#   ''/''
#   </VBZ
#   br/NN
#   //NNP
#   >/NNP
#   If/IN
#   you/PRP
#   like/VBP
#   apple/NN
#   products/NNS
#   a/DT
#   must/MD
#   have/VB
#   item/NN
#   ./.
#   The/DT
#   only/JJ
#   draw/NN
#   back/RB
#   ,/,
#   shipping/VBG
#   cost/NN
#   ./.
#   These/DT
#   are/VBP
#   very/RB
#   heavy/JJ
#   ./.)

# %%
sia = SentimentIntensityAnalyzer()

# %%
sia.polarity_scores("It is so bad")
# Out:
# {'neg': 0.6, 'neu': 0.4, 'pos': 0.0, 'compound': -0.6696}

# %%
#Here we can see our old review example value
sia.polarity_scores(review_example)
# Out:
# {'neg': 0.0, 'neu': 0.807, 'pos': 0.193, 'compound': 0.7717}

# %%
res = {}
for i, row in tqdm(df_train.iterrows(), total = len(df_train)):
    text = row["Text"]
    myid = row["Id"]
    res[myid] = sia.polarity_scores(text)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
res
# Out:
# {1: {'neg': 0.0, 'neu': 0.695, 'pos': 0.305, 'compound': 0.9441},
#  2: {'neg': 0.079, 'neu': 0.853, 'pos': 0.068, 'compound': -0.1027},
#  3: {'neg': 0.091, 'neu': 0.754, 'pos': 0.155, 'compound': 0.8265},
#  4: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  5: {'neg': 0.0, 'neu': 0.552, 'pos': 0.448, 'compound': 0.9468},
#  6: {'neg': 0.029, 'neu': 0.809, 'pos': 0.163, 'compound': 0.883},
#  7: {'neg': 0.034, 'neu': 0.693, 'pos': 0.273, 'compound': 0.9346},
#  8: {'neg': 0.0, 'neu': 0.52, 'pos': 0.48, 'compound': 0.9487},
#  9: {'neg': 0.0, 'neu': 0.851, 'pos': 0.149, 'compound': 0.6369},
#  10: {'neg': 0.0, 'neu': 0.705, 'pos': 0.295, 'compound': 0.8313},
#  11: {'neg': 0.017, 'neu': 0.846, 'pos': 0.137, 'compound': 0.9746},
#  12: {'neg': 0.113, 'neu': 0.887, 'pos': 0.0, 'compound': -0.7579},
#  13: {'neg': 0.031, 'neu': 0.923, 'pos': 0.046, 'compound': 0.296},
#  14: {'neg': 0.0, 'neu': 0.355, 'pos': 0.645, 'compound': 0.9466},
# ...

# %%
#Adding the scores to main dataset to compare with real score
vaders = pd.DataFrame(res).T
vaders = vaders.reset_index().rename(columns={"index":"Id"})
vaders = vaders.merge(df_train, how = "left")

# %%
vaders
# Out:
#       Id    neg    neu    pos  compound   ProductId          UserId  \
# 0      1  0.000  0.695  0.305    0.9441  B001E4KFG0  A3SGXH7AUHU8GW
# 1      2  0.079  0.853  0.068   -0.1027  B00813GRG4  A1D87F6ZCVE5NK
# 2      3  0.091  0.754  0.155    0.8265  B000LQOCH0   ABXLMWJIXXAIN
# 3      4  0.000  1.000  0.000    0.0000  B000UA0QIQ  A395BORC6FGVXV
# 4      5  0.000  0.552  0.448    0.9468  B006K2ZZ7K  A1UQRSCLF8GW1T
# ..   ...    ...    ...    ...       ...         ...             ...
# 495  496  0.000  0.554  0.446    0.9725  B000G6RYNE   APGAA43E3WPN7
# 496  497  0.059  0.791  0.150    0.8215  B000G6RYNE    ABR7HU5H1KNE
# 497  498  0.025  0.762  0.212    0.9848  B000G6RYNE   AJQD2WWJYOYFQ
# 498  499  0.041  0.904  0.055    0.1280  B000G6RYNE  A16YH487W9ZYO0
# 499  500  0.000  0.678  0.322    0.9811  B000G6RYNE   A83YQC1XOU4CS
#
#                          ProfileName  HelpfulnessNumerator  \
# 0                         delmartian                     1
# ...

# %%
ax = sns.barplot(data=vaders, x="Score", y="compound")
ax.set_title("Compound Score by Amazon Star Review")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig, axs = plt.subplots(1,3,figsize = (15,5))
sns.barplot(data = vaders, x = "Score", y = "pos", ax = axs[0])
sns.barplot(data = vaders, x = "Score", y = "neu", ax = axs[1])
sns.barplot(data = vaders, x = "Score", y = "neg", ax = axs[2])
axs[0].set_title("Positive")
axs[1].set_title("Neutral")
axs[2].set_title("Negative")
plt.show()
